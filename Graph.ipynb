# %% [markdown]
# <a href="https://colab.research.google.com/github/martincortinaescudero/Plants_recognition_project/blob/main/Graph.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Data from the table
data = {
    "The US": [78, 10, 12],
    "Germany": [12, 72, 15],
    "Mexico": [0, 10, 90]
}

# Index for the categories
index = ["Farming", "Industry", "Raw materials"]

# Creating DataFrame
df = pd.DataFrame(data, index=index)

# Transposing the DataFrame to have countries on the x-axis and activities as colors
df_transposed = df.T

# Plotting the bar graph with countries on the x-axis and custom colors (#bcbd22)
df_transposed.plot(kind="bar", figsize=(10, 6), width=0.8, color=["#bcbd22", "#1f77b4", "#ff9900"])

# Adding labels and title
plt.ylabel("Percentage")
plt.xlabel("Country")
plt.title("Comparison of Farms, Industry, and Raw Materials in The US, Germany, and Mexico")
plt.xticks(rotation=0);

# Display the plot
plt.show()

'''
Blue: #1f77b4
Orange: #ff7f0e
Green: #2ca02c
Red: #d62728
Purple: #9467bd
Brown: #8c564b
Pink: #e377c2
Gray: #7f7f7f
Olive: #bcbd22
Cyan: #17becf

Salmon: #ffa07a
Peach: #ffcc99
Gold: #ff9900
'''
# Out:
# '\nBlue: #1f77b4\nOrange: #ff7f0e\nGreen: #2ca02c\nRed: #d62728\nPurple: #9467bd\nBrown: #8c564b\nPink: #e377c2\nGray: #7f7f7f\nOlive: #bcbd22\nCyan: #17becf\n\nSalmon: #ffa07a\nPeach: #ffcc99\nGold: #ff9900\n'

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Data from the table
data = {
    "The US": [78, 10, 12],
    "Germany": [12, 72, 15],
    "Mexico": [0, 10, 90]
}

# Index for the categories
index = ["Farming", "Industry", "Raw materials"]

# Creating DataFrame
df = pd.DataFrame(data, index=index)

# Transposing the DataFrame to have countries on the x-axis and activities as colors
df_transposed = df.T

# Plotting the bar graph with countries on the x-axis and custom colors
ax = df_transposed.plot(kind="bar", figsize=(10, 6), width=0.8, color=["#bcbd22", "#1f77b4", "#ff9900"])

# Adding labels and title
plt.ylabel("Percentage")
plt.xlabel("Country")
plt.title("Comparison of Farms, Industry, and Raw Materials in The US, Germany, and Mexico")
plt.xticks(rotation=0)

# Adding values on top of the bars
for container in ax.containers:
    for bar in container:
        height = bar.get_height()
        ax.annotate(f'{height}%',
                    xy=(bar.get_x() + bar.get_width() / 2, height),
                    xytext=(0, 3),  # 3 points vertical offset
                    textcoords="offset points",
                    ha='center', va='bottom')

# Adding a legend outside the plot area
ax.legend(title='Categories', bbox_to_anchor=(1.05, 1), loc='upper left')

# Adjusting layout to make room for the legend
plt.tight_layout()

# Display the plot
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Data from the table
data = {
    "The US": [78, 10, 12],
    "Germany": [12, 72, 15],
    "Mexico": [0, 10, 90]
}

# Index for the categories
index = ["Farming", "Industry", "Raw materials"]

# Creating DataFrame
df = pd.DataFrame(data, index=index)

# Transposing the DataFrame to have countries on the x-axis and activities as colors
df_transposed = df.T

# Plotting the bar graph with countries on the x-axis and custom colors
ax = df_transposed.plot(kind="bar", figsize=(10, 6), width=0.8, color=["#bcbd22", "#1f77b4", "#ff9900"])

# Adding labels and title
plt.ylabel("Percentage")
plt.xlabel("Country")
plt.title("Comparison of Farms, Industry, and Raw Materials in The US, Germany, and Mexico")
plt.xticks(rotation=0)

# Adding values on top of the bars
for container in ax.containers:
    for bar in container:
        height = bar.get_height()
        ax.annotate(f'{height}%',
                    xy=(bar.get_x() + bar.get_width() / 2, height),
                    xytext=(0, -15),  # 3 points vertical offset
                    textcoords="offset points",
                    ha='center', va='bottom')

# Display the plot
plt.show()
